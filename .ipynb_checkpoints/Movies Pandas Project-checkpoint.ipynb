# %% [markdown]
# # Pandas Movies Data Analysis Project

# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
movies = pd.read_csv('movies.csv')
movies
# Out:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# 5            6                                        Heat (1995)
# 6            7                                     Sabrina (1995)
# 7            8                                Tom and Huck (1995)
# 8            9                                Sudden Death (1995)
# 9           10                                   GoldenEye (1995)
# 10          11                     American President, The (1995)
# 11          12                 Dracula: Dead and Loving It (1995)
# 12          13                                       Balto (1995)
# 13          14                                       Nixon (1995)
# 14          15                            Cutthroat Island (1995)
# 15          16                                      Casino (1995)
# 16          17                       Sense and Sensibility (1995)
# 17          18                                  Four Rooms (1995)
# 18          19              Ace Ventura: When Nature Calls (1995)
# 19          20                                 Money Train (1995)
# 20          21                                  Get Shorty (1995)
# 21          22                                     Copycat (1995)
# 22          23                                   Assassins (1995)
# 23          24                                      Powder (1995)
# 24          25                           Leaving Las Vegas (1995)
# 25          26                                     Othello (1995)
# 26          27                                Now and Then (1995)
# 27          28                                  Persuasion (1995)
# 28          29  City of Lost Children, The (Cité des enfants p...
# 29          30  Shanghai Triad (Yao a yao yao dao waipo qiao) ...
# ...        ...                                                ...
# 45813   176207                             The Final Storm (2010)
# 45814   176211                              In a Heartbeat (2017)
# 45815   176213                      Blood, Sweat and Tears (2015)
# 45816   176215                                Jungle Woman (1944)
# 45817   176217                           To Be Fat Like Me (2007)
# 45818   176219                                 Cadet Kelly (2002)
# 45819   176221             The Scheming Gambler's Paradise (1905)
# 45820   176223                The Man with the Rubber Head (1901)
# 45821   176225                    The Living Playing Cards (1905)
# 45822   176227                       The Hilarious Posters (1906)
# 45823   176229                         The Devilish Tenant (1909)
# 45824   176231                     The Untameable Whiskers (1904)
# 45825   176233            The Imperceptable Transmutations (1904)
# 45826   176235            Pooh's Heffalump Halloween Movie (2005)
# 45827   176237                            The One-Man Band (1900)
# 45828   176239            The Fat and Lean Wrestling Match (1900)
# 45829   176245                                 Deep Hearts (1981)
# 45830   176249                                         Mom (2017)
# 45831   176251                           The Morning After (2015)
# 45832   176253                   St. Michael Had a Rooster (1972)
# 45833   176255                            House of Horrors (1946)
# 45834   176257                   Shadow of the Blair Witch (2000)
# 45835   176259                         The Burkittsville 7 (2000)
# 45836   176263                             Caged Heat 3000 (1995)
# 45837   176267                                  Robin Hood (1991)
# 45838   176269                                             Subdue
# 45839   176271                         Century of Birthing (2011)
# 45840   176273                                    Betrayal (2003)
# 45841   176275                            Satan Triumphant (1917)
# 45842   176279                                    Queerama (2017)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# 5                            Action|Crime|Thriller
# 6                                   Comedy|Romance
# 7                               Adventure|Children
# 8                                           Action
# 9                        Action|Adventure|Thriller
# 10                            Comedy|Drama|Romance
# 11                                   Comedy|Horror
# 12                    Adventure|Animation|Children
# 13                                           Drama
# 14                        Action|Adventure|Romance
# 15                                     Crime|Drama
# 16                                   Drama|Romance
# 17                                          Comedy
# 18                                          Comedy
# 19              Action|Comedy|Crime|Drama|Thriller
# 20                           Comedy|Crime|Thriller
# 21             Crime|Drama|Horror|Mystery|Thriller
# 22                           Action|Crime|Thriller
# 23                                    Drama|Sci-Fi
# 24                                   Drama|Romance
# 25                                           Drama
# 26                                  Children|Drama
# 27                                   Drama|Romance
# 28          Adventure|Drama|Fantasy|Mystery|Sci-Fi
# 29                                     Crime|Drama
# ...                                            ...
# 45813               Action|Horror|Mystery|Thriller
# 45814                            Animation|Romance
# 45815                                        Drama
# 45816                         Drama|Fantasy|Horror
# 45817                               Children|Drama
# 45818                                       Comedy
# 45819                           (no genres listed)
# 45820                        Comedy|Fantasy|Sci-Fi
# 45821                                      Fantasy
# 45822                               Comedy|Fantasy
# 45823                               Comedy|Fantasy
# 45824                           (no genres listed)
# 45825                           (no genres listed)
# 45826                           Animation|Children
# 45827                      Action|Fantasy|Thriller
# 45828                               Comedy|Fantasy
# 45829                                  Documentary
# 45830                         Crime|Drama|Thriller
# 45831                                 Comedy|Drama
# 45832                           (no genres listed)
# 45833                      Horror|Mystery|Thriller
# 45834                               Horror|Mystery
# 45835                                       Horror
# 45836                                       Sci-Fi
# 45837                         Action|Drama|Romance
# 45838                               Children|Drama
# 45839                                        Drama
# 45840                        Action|Drama|Thriller
# 45841                           (no genres listed)
# 45842                           (no genres listed)
#
# [45843 rows x 3 columns]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45843 entries, 0 to 45842
# Data columns (total 3 columns):
# movieId    45843 non-null int64
# title      45843 non-null object
# genres     45843 non-null object
# dtypes: int64(1), object(2)
# memory usage: 1.0+ MB

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# # Creating new year and title features

# %%
movies['year'] = movies['title'].apply(lambda x: re.findall('\(\d+\)$', x))

# %%
movies['title'] = movies['title'].apply(lambda x: re.sub(r'\(\d+\)$', '', x))

# %%
movies.head()
# Out:
#    movieId                         title  \
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II
#
#                                         genres      year
# 0  Adventure|Animation|Children|Comedy|Fantasy  [(1995)]
# 1                   Adventure|Children|Fantasy  [(1995)]
# 2                               Comedy|Romance  [(1995)]
# 3                         Comedy|Drama|Romance  [(1995)]
# 4                                       Comedy  [(1995)]

# %% [markdown]
# # Checking if a movie has no year value

# %%
#noyears = movies.index.values[np.where(movies.year.apply(lambda x: ''.join(x)).apply(lambda x: x[1:5]) == '')]
#noyears
noyears = np.where(movies.year.apply(lambda x: len(x)==0))
print(noyears)
# Out:
# (array([ 8495,  8635,  8962,  9171,  9233,  9688,  9781,  9929, 10018,
#        10047, 10173, 10237, 10607, 10861, 11722, 11771, 11888, 11917,
#        12213, 12527, 12583, 12883, 12915, 15690, 15845, 15846, 15847,
#        15857, 16414, 16680, 16780, 16814, 16947, 16983, 17063, 17209,
#        17225, 17303, 17304, 17308, 17354, 17362, 17397, 17434, 17450,
#        17555, 17640, 17641, 17642, 17768, 17778, 17792, 17852, 17935,
#        17996, 18062, 18069, 18076, 18319, 18458, 18463, 18583, 18586,
#        18598, 18630, 18699, 18724, 18780, 18883, 18896, 18993, 19019,
#        19044, 19054, 19077, 19085, 19091, 19124, 19181, 19217, 19230,
#        19287, 19301, 19306, 19310, 19358, 19407, 19409, 19445, 19450,
#        19453, 19456, 19472, 19493, 19501, 19556, 19578, 19600, 19717,
#        19768, 19947, 20051, 20117, 20162, 20202, 20436, 20477, 20494,
#        20502, 20544, 20592, 20618, 20646, 20665, 20710, 20735, 20769,
#        20797, 20798, 20816, 20863, 20954, 21008, 21109, 21223, 21224,
#        21226, 21227, 21289, 21290, 21311, 21346, 21363, 21420, 21421,
#        21438, 21445, 21493, 21496, 21520, 21552, 21561, 21634, 21657,
#        21670, 21671, 21672, 21717, 21719, 21740, 21746, 21800, 21830,
#        21831, 21859, 21881, 21887, 21943, 21976, 21997, 22019, 22031,
#        22041, 22063, 22101, 22139, 22148, 22180, 22187, 22196, 22197,
#        22209, 22235, 22239, 22241, 22245, 22256, 22262, 22272, 22287,
#        22327, 22349, 22379, 22450, 22470, 22471, 22541, 22566, 22567,
#        22606, 22645, 22674, 22703, 22749, 22810, 22811, 22834, 22903,
#        22904, 22910, 22965, 22998, 23115, 23167, 23261, 23356, 23357,
#        23418, 23419, 23497, 23673, 23895, 24128, 24407, 24635, 24804,
#        24813, 25102, 27094, 27707, 27726, 27802, 27966, 28077, 28525,
#        28570, 28833, 28850, 28914, 29075, 29329, 29585, 29929, 30044,
#        30407, 30644, 30712, 30846, 30919, 31144, 31391, 31538, 31542,
#        31589, 31758, 31774, 32243, 32478, 32545, 32758, 32949, 33016,
#        33052, 33069, 33112, 33145, 33357, 33523, 33693, 34105, 34564,
#        34599, 34611, 34614, 34718, 34728, 34731, 34759, 34769, 34774,
#        35003, 35034, 35278, 35457, 35607, 35612, 35664, 35679, 35760,
#        35858, 35956, 36149, 36150, 36207, 36217, 36300, 36423, 36441,
#        36522, 36528, 36752, 36856, 36859, 36872, 36894, 37037, 37280,
#        37398, 37401, 37460, 37547, 37619, 37623, 37972, 37979, 37993,
#        38175, 38247, 38257, 38264, 38669, 38881, 39097, 39211, 39255,
#        39272, 39273, 39287, 39368, 39378, 39409, 39421, 39630, 39687,
#        39738, 39797, 39800, 39852, 39954, 40135, 40158, 40196, 40222,
#        40313, 40432, 40434, 40468, 40494, 40555, 40558, 40744, 41096,
#        41137, 41143, 41305, 41371, 41409, 41426, 41472, 41567, 41588,
#        41760, 41905, 41954, 41979, 42017, 42082, 42264, 42380, 42411,
#        42547, 42655, 42692, 42730, 42794, 42843, 42848, 42934, 42939,
#        43139, 43308, 43451, 43572, 43747, 43893, 43953, 44008, 44010,
#        44074, 44333, 44385, 44436, 44469, 44552, 44669, 44737, 45156,
#        45174, 45354, 45446, 45454, 45524, 45560, 45579, 45714, 45775,
#        45787, 45838], dtype=int64),)

# %%
#np.array([]).astype('int64')
print(np.where(movies.year.apply(lambda x: len(x)>1)))
# Out:
# (array([], dtype=int64),)

# %%
ftotn = pd.DataFrame(movies.loc[43139])
ftsto = pd.DataFrame(movies.loc[42730])
ftotn
# Out:
#                     43139
# movieId            169656
# title    The Glass Castle
# genres              Drama
# year                   []

# %%
ftsto
# Out:
#                                            42730
# movieId                                   168730
# title    Mumford & Sons: We Wrote This Yesterday
# genres                        (no genres listed)
# year                                          []

# %% [markdown]
# # Cleaning the year feature

# %%
def clean_year(x):
    if len(x) != 1:
        return np.nan
    else:
        return int(re.search(r'\d+', x[0]).group())

# %%
movies.year = movies.year.apply(clean_year)

# %%
movies.head()
# Out:
#    movieId                         title  \
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II
#
#                                         genres    year
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995.0
# 1                   Adventure|Children|Fantasy  1995.0
# 2                               Comedy|Romance  1995.0
# 3                         Comedy|Drama|Romance  1995.0
# 4                                       Comedy  1995.0

# %% [markdown]
# # Cleaning the genres feature

# %%
def clean_genres(x):
    l = x.split('|')
    if len(l) == 0 or x=='(no genres listed)':
        return []
    return l

# %%
movies.genres = movies.genres.apply(clean_genres)

# %%
movies.head()
# Out:
#    movieId                         title  \
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II
#
#                                               genres    year
# 0  [Adventure, Animation, Children, Comedy, Fantasy]  1995.0
# 1                     [Adventure, Children, Fantasy]  1995.0
# 2                                  [Comedy, Romance]  1995.0
# 3                           [Comedy, Drama, Romance]  1995.0
# 4                                           [Comedy]  1995.0

# %% [markdown]
# # Visualizing the years

# %%
movies.year.plot(kind='hist', grid=True)

# %%
movies.year.plot(kind='box', grid=True)

# %% [markdown]
# # How many movies do not have a year value? Display the last 20

# %% [markdown]
# ### Answer: 398

# %%
movies[movies.year.isnull()][379:399]
# Out:
#        movieId                                           title  \
# 44333   172451                               Irwin & Fran 2013
# 44385   172557                                Shivering Trunks
# 44436   172673                        Supermassive Black Holes
# 44469   172739                               Игра на выбывание
# 44552   172915                                   Falling Skies
# 44669   173191                            Neither Wolf Nor Dog
# 44737   173347                Philosophy: A Guide to Happiness
# 45156   174447                                    A Gray State
# 45174   174485                                   Salad Fingers
# 45354   174953                                       Mundo Cão
# 45446   175335                  The Garden of Afflictions 2017
# 45454   175353                                       Abduction
# 45524   175511                                 Engineering Red
# 45560   175605                           S.W.A.T.: Under Siege
# 45579   175651  All Superheroes Must Die 2: The Last Superhero
# 45714   175985                  The Land Where the Blues Began
# 45775   176127                Lauri Mäntyvaaran tuuheet ripset
# 45787   176151                                           Aprel
# 45838   176269                                          Subdue
#
#                   genres  year
# 44333                 []   NaN
# 44385                 []   NaN
# 44436      [Documentary]   NaN
# 44469                 []   NaN
# 44552                 []   NaN
# 44669            [Drama]   NaN
# 44737      [Documentary]   NaN
# 45156                 []   NaN
# 45174                 []   NaN
# 45354                 []   NaN
# 45446                 []   NaN
# 45454   [Drama, Fantasy]   NaN
# 45524                 []   NaN
# 45560                 []   NaN
# 45579  [Mystery, Sci-Fi]   NaN
# 45714                 []   NaN
# 45775                 []   NaN
# 45787     [Crime, Drama]   NaN
# 45838  [Children, Drama]   NaN

# %% [markdown]
# # List Years in Descending and Titles in Ascending Orders

# %%
movies.sort_values(by=['year', 'title'], ascending=[False, True])
# Out:
#        movieId                                              title  \
# 43587   170783                                     1 Mile to You
# 45258   174679                                           1 Night
# 45332   174893                                              2:22
# 43656   170941                                         3 Idiotas
# 45382   175151                                             78/52
# 45336   174901                                  A Bag of Marbles
# 42295   167640                               A Cure for Wellness
# 43867   171439                                       A Dark Song
# 42178   167380                                   A Dog's Purpose
# 44499   172807                                      A Family Man
# 42930   169220                                 A Fantastic Woman
# 42674   168610                                     A Ghost Story
# 42925   169210                                       A Good Wife
# 44916   173745                                 A Stork's Journey
# 42373   167814                                         A Wedding
# 45034   174005                                     Aaron's Blood
# 45212   174565                      Abacus: Small Enough to Jail
# 45339   174911  Addicted to Porn: Chasing the Cardboard Butter...
# 43627   170881                                 After Porn Ends 2
# 42530   168240                                        Afterimage
# 43575   170751                                         Aftermath
# 44450   172701                                        Alcoholist
# 43428   170407                                         Alibi.com
# 43269   169984                                   Alien: Covenant
# 44934   173783                               All About the Money
# 43432   170423                                       All Nighter
# 30709   135139                                 Allegiant: Part 2
# 42919   169198                                     Almost Adults
# 45168   174473                                          Altitude
# 42910   169180                                    American Fable
# ...        ...                                                ...
# 20798   101305                           Unspeakable Acts (1990)
# 36894   152884                                     Vaastu Shastra
# 31391   136880                                       Vaastupurush
# 36522   151955                                             Veljet
# 37037   153184                                         Vergeef me
# 19456    96242                       Viimeiset rotannahat (1985)
# 21421   103547                                       Vile (2011)
# 33357   142490                                               Viva
# 37280   153714                                          Vogelfrei
# 36752   152523                 Vous êtes très jolie, mademoiselle
# 35956   150020                                            Vrijdag
# 23497   110748                                  Wake Wood (2010)
# 17641    88454                             Waking Madison (2010)
# 19445    96200              War of the Dead - Stone's War (2011)
# 15847    80235                          Wedding Song, The (2008)
# 22810   108405                        Weddings and Babies (1958)
# 44010   171753                                   Wet and Reckless
# 17768    89016  What Did the Lady Forget? (Shukujo wa nani o w...
# 17063    86173  White Hell of Pitz Palu, The (Die weiße Hölle ...
# 42939   169240                            Whn the day had no name
# 42934   169230                                     Winning Favour
# 21520   103838   Witches' Hammer (Kladivo na carodejnice) (1970)
# 31589   137443                                 Wolves In The Snow
# 20544   100240       Woman's Face, A (En kvinnas ansikte) (1938)
# 21719   104599        World According to Dick Cheney, The (2013)
# 22904   108754                                      Xingu (2012)
# 22811   108407                                      Yanco (1961)
# 34599   146082                                    Yedyanchi Jatra
# 35457   148677                                   Ουζερί Τσιτσάνης
# 44469   172739                                  Игра на выбывание
#
#                                                   genres    year
# 43587                                                 []  2017.0
# 45258                                   [Drama, Romance]  2017.0
# 45332                                  [Drama, Thriller]  2017.0
# 43656                                                 []  2017.0
# 45382                                      [Documentary]  2017.0
# 45336                                            [Drama]  2017.0
# 42295                 [Drama, Horror, Mystery, Thriller]  2017.0
# 43867                                    [Drama, Horror]  2017.0
# 42178                                    [Comedy, Drama]  2017.0
# 44499                                            [Drama]  2017.0
# 42930                                            [Drama]  2017.0
# 42674                                            [Drama]  2017.0
# 42925                                            [Drama]  2017.0
# 44916                             [Adventure, Animation]  2017.0
# 42373                                                 []  2017.0
# 45034                                                 []  2017.0
# 45212                                      [Documentary]  2017.0
# 45339                                      [Documentary]  2017.0
# 43627                                      [Documentary]  2017.0
# 42530                                            [Drama]  2017.0
# 43575                                  [Drama, Thriller]  2017.0
# 44450                                         [Thriller]  2017.0
# 43428                                           [Comedy]  2017.0
# 43269                 [Action, Horror, Sci-Fi, Thriller]  2017.0
# 44934                                                 []  2017.0
# 43432                                           [Comedy]  2017.0
# 30709                       [Adventure, Romance, Sci-Fi]  2017.0
# 42919                           [Comedy, Drama, Romance]  2017.0
# 45168                                 [Action, Thriller]  2017.0
# 42910                                         [Thriller]  2017.0
# ...                                                  ...     ...
# 20798                                            [Drama]     NaN
# 36894                                                 []     NaN
# 31391                                                 []     NaN
# 36522                                      [Documentary]     NaN
# 37037                                                 []     NaN
# 19456                                           [Comedy]     NaN
# 21421                                           [Horror]     NaN
# 33357                                                 []     NaN
# 37280                                                 []     NaN
# 36752                                                 []     NaN
# 35956                                                 []     NaN
# 23497                           [Drama, Horror, Mystery]     NaN
# 17641                                            [Drama]     NaN
# 19445  [Action, Adventure, Horror, Sci-Fi, Thriller, ...     NaN
# 15847                                       [Drama, War]     NaN
# 22810                                   [Drama, Romance]     NaN
# 44010                                                 []     NaN
# 17768                                    [Comedy, Drama]     NaN
# 17063                         [Action, Adventure, Drama]     NaN
# 42939                                                 []     NaN
# 42934                                                 []     NaN
# 21520                                    [Drama, Horror]     NaN
# 31589                   [Action, Crime, Drama, Thriller]     NaN
# 20544                                            [Drama]     NaN
# 21719                                      [Documentary]     NaN
# 22904                                 [Adventure, Drama]     NaN
# 22811                                            [Drama]     NaN
# 34599                          [Children, Comedy, Drama]     NaN
# 35457                                                 []     NaN
# 44469                                                 []     NaN
#
# [45843 rows x 4 columns]

# %% [markdown]
# # Getting Movie Counts by Genre and Plotting

# %%
movies.movieId.is_unique
# Out:
# True

# %%
movies.title.is_unique
# Out:
# False

# %%
movies.head()
# Out:
#    movieId                         title  \
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II
#
#                                               genres    year
# 0  [Adventure, Animation, Children, Comedy, Fantasy]  1995.0
# 1                     [Adventure, Children, Fantasy]  1995.0
# 2                                  [Comedy, Romance]  1995.0
# 3                           [Comedy, Drama, Romance]  1995.0
# 4                                           [Comedy]  1995.0

# %%
cnt = {}
def genre_count(l):
    for x in l:
        if x in cnt:
            cnt[x] += 1
        else:
            cnt[x] = 1
    return cnt

# %%
count = movies['genres'].apply(genre_count)
genres = count[0]
genres
# Out:
# {'Action': 5775,
#  'Adventure': 3369,
#  'Animation': 1942,
#  'Children': 2182,
#  'Comedy': 13002,
#  'Crime': 4247,
#  'Documentary': 4122,
#  'Drama': 19806,
#  'Fantasy': 2212,
#  'Film-Noir': 360,
#  'Horror': 4448,
#  'IMAX': 197,
#  'Musical': 1079,
#  'Mystery': 2274,
#  'Romance': 6069,
#  'Sci-Fi': 2847,
#  'Thriller': 6761,
#  'War': 1544,
#  'Western': 1028}

# %%
plt.figure(figsize=(17,7))

plt.bar(range(len(genres)), list(genres.values()), align='center')
plt.xticks(range(len(genres)), list(genres.keys()))
# Out:
# ([<matplotlib.axis.XTick at 0x21be85e4710>,
#   <matplotlib.axis.XTick at 0x21be85e4e80>,
#   <matplotlib.axis.XTick at 0x21be85e7198>,
#   <matplotlib.axis.XTick at 0x21be8630f60>,
#   <matplotlib.axis.XTick at 0x21be86395f8>,
#   <matplotlib.axis.XTick at 0x21be8639c50>,
#   <matplotlib.axis.XTick at 0x21be863d320>,
#   <matplotlib.axis.XTick at 0x21be863d9b0>,
#   <matplotlib.axis.XTick at 0x21be8644080>,
#   <matplotlib.axis.XTick at 0x21be8644710>,
#   <matplotlib.axis.XTick at 0x21be8644da0>,
#   <matplotlib.axis.XTick at 0x21be864b470>,
#   <matplotlib.axis.XTick at 0x21be864bb00>,
#   <matplotlib.axis.XTick at 0x21be86531d0>,
#   <matplotlib.axis.XTick at 0x21be8653860>,
#   <matplotlib.axis.XTick at 0x21be8653ef0>,
#   <matplotlib.axis.XTick at 0x21be86595c0>,
#   <matplotlib.axis.XTick at 0x21be8659c50>,
#   <matplotlib.axis.XTick at 0x21be865e320>],
#  <a list of 19 Text xticklabel objects>)
